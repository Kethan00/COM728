# %%
# import other python files
import Options_module
import CSV_Data_Processing_Module
import Pandas_Data_Processing_Module
import Data_visualization_MATPLOTLIB_Module

#importing all functions from the imported modules to progress the below functions.
from Options_module import*
from CSV_Data_Processing_Module import*
from Pandas_Data_Processing_Module import*
from Data_visualization_MATPLOTLIB_Module import*

#creating a empty list to store data
data_frame=[]

def run():
    while True:
        option = options()
        if option == 1:
            selected_option = options(1)
            if selected_option == 1:
                employee_details(data_set)
                print(125*'-')
            elif selected_option == 2:
                professional_details(data_set)
                print(125*'-')
            elif selected_option == 3:
                department_details(data_set)
                print(125*'-')
            elif selected_option == 4:
                important_details(data_set)
                print(125*'-')
            elif selected_option == 5:
                run()
            else:
                print("Uh-oh, that option isn't correct. Could you select a valid one please?")
         
            
        elif option == 2:
            print("Select Option 2...!!!")
            selected_option = options(2)
            if selected_option ==1:
                top_job_roles_by_education_level(D)
                print(125*'-')
            elif selected_option == 2:
                average_monthly_rate(D)
                print(125*'-')
            elif selected_option == 3:
                tenure_of_employment(D)
                print(125*'-')
            elif selected_option == 4:
                monthly_income(D)
                print(125*'-')
            elif selected_option == 5:
                run()
            else:
                print("Whoops! It seems you've chosen an incorrect option. Please pick a correct one to move forward!")

        elif option == 3:
            print("Select Option 3...!!!")
            selected_option = options(3)
            if selected_option == 1:
                proportion_employees(D)
                print(125*'-')
            elif selected_option ==2:
                frequency_of_training(D)
                print(125*'-')
            elif selected_option == 3:
                job_satisfaction_by_department(D)
                print(125*'-')
            elif selected_option == 4:
                Salary_hike_across_jobroles(D)
                print(125*'-')
            elif selected_option == 5:
                run()
            else:
                print("That doesn't seem like a valid option. Let's try again with a correct choice!")
        
        elif option == 4:
            print(125*'-')
            run()
          
            
        else:
            print("The option you selected is not valid.Kindly select an appropriate option.")
        
        
run()
